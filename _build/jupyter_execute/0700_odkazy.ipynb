# %% [markdown]
# % #   <font color='#4B9DA9'> level 1 </font>
# % ##  <font color='#547792'> level 2 </font>
# % ### <font color='#E37434'> level 3 </font>
# % {dropdown} <font color='#84B179'> Text </font>
#
# #   <font color='#4B9DA9'> Odkazy </font>
#
# ##  <font color='#547792'> Sphinx </font>
#
# ### <font color='#E37434'> Dokumentácia </font>
#
# * https://sphinx-design.readthedocs.io/en/latest/index.html
# * https://sphinx-themes.org/
# * https://sphinxthemes.com/
# * https://sphinx-book-theme.readthedocs.io/en/stable/index.html
#
# ### <font color='#E37434'> Rozšírenia </font>
#
# * https://awesomesphinx.useblocks.com/index.html
#
# ##  <font color='#547792'> Markdown </font>
#
# * [Špecifikácia](https://spec.commonmark.org/)
#
#
# ##  <font color='#547792'> LaTex </font>
#
# * https://en.wikibooks.org/wiki/LaTeX
