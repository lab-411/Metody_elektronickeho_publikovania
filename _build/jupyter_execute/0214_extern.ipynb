# %% [markdown]
# % #   <font color='#4B9DA9'> level 1 </font>
# % ##  <font color='#547792'> level 2 </font>
# % ### <font color='#E37434'> level 3 </font>
# % {dropdown} <font color='#84B179'> Text </font>
#
# #   <font color='#4B9DA9'> Externé dokumenty </font>
#
# Parser externých dokumentov
#
# * .tex
# * .ipnb
# * .html
#
# ##  <font color='#547792'> Odkazy </font>
#
# ### <font color='#E37434'> *{include}* </font>
#
# ### <font color='#E37434'> *{literalinclude}* </font>
#
# Vloží externý súbor tak, ako keby bol súčasťou dokumentu.
#
#     {include.literal}
#
# ### <font color='#E37434'> *{embed}* </font>
#
# Indexuje vložený dokument. Skráteny formát
#
#     ![](xref:spec#admonition)
